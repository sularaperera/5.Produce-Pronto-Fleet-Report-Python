# %% [markdown]
# # Code

# %%
import pandas as pd
from pathlib import Path
import re, glob
from datetime import datetime

# %%
folder_path = Path(r'./data/')
file = list(folder_path.rglob('*Fleetpin*.csv'))
df = pd.read_csv(file[0])
selector = ['Name', 'Odo / Hours / Hubo', 'Next Service Due', 'RUC Due', 'WoF Due', 'Rego Due']
df = df[selector]

# %%
df
# Out:
#                                        Name          Odo / Hours / Hubo  \
# 0                      101 - JLM368 - Hiace                   371971 km
# 1                       102 - LGH14 - Hiace                   421977 km
# 2                       103 - LPB86 - Hiace                   293533 km
# 3                      104 - LPB87 -  Hiace                   271762 km
# 4                      105 - LPK832 - Hiace                   297725 km
# 5   106 - KBW622 - KK Hiace (small chiller)                   251315 km
# 6                    107 - LZN203 - Transit                   195070 km
# 7                   110 - PHK242 - Sprinter  103319 km\n\n\n/ 103245 km
# 8                   111 - NLS732 - Sprinter  218029 km\n\n\n/ 173971 km
# 9                   112 - NNG481 - Sprinter  220859 km\n\n\n/ 223624 km
# 10                   115 - NRG53 - Sprinter                   221690 km
# 11                  116 - PNQ294 - Sprinter    44454 km\n\n\n/ 44477 km
# 12                  117 - PPT252 - SPRINTER    40698 km\n\n\n/ 40686 km
# 13                  118 - PPT251 - Sprinter    28953 km\n\n\n/ 28950 km
# 14              201 - NQE185 - Sprinter WLG                   166815 km
# 15                     202 - LMZ837 - Hiace                   479003 km
# 16                  203 - MWG556 - Sprinter                   355106 km
# 17                     204 - LPK831 - Hiace                   425967 km
# 18                  205 - NDU364 - Sprinter   262334 km\n\n\n/ 95295 km
# 19                       220 - NBU574 - DAF    80472 km\n\n\n/ 79845 km
# 20                     301 - MET814 - Hiace                   637227 km
# 21                     302 - LMZ835 - Hiace                   425735 km
# 22                  303 - NEF984 - Sprinter                   164597 km
# 23                  305 - MNW157 - Sprinter                   311193 km
# 24                   306 - NPR791- Sprinter  204883 km\n\n\n/ 204900 km
#
#    Next Service Due     RUC Due     WoF Due    Rego Due
# 0         375000 km  388652\nkm  16/11/2023  24/11/2023
# 1         435000 km  436000\nkm  30/04/2024  19/03/2024
# 2         294500 km  301948\nkm  10/08/2024  15/08/2024
# 3         283600 km  288404\nkm  13/09/2023  15/08/2024
# 4         314404 km  308892\nkm  23/08/2024  26/08/2024
# 5         260000 km  268000\nkm  30/11/2023  22/01/2024
# 6         200000 km  204390\nkm  28/08/2024  26/02/2024
# 7         120000 km  111000\nkm  13/09/2023  28/06/2024
# 8         225575 km  180002\nkm  29/07/2023  28/04/2024
# 9         248459 km  236167\nkm  25/11/2023  31/05/2024
# 10        225310 km  231000\nkm  16/09/2023  27/07/2024
# 11         40000 km   51000\nkm  24/10/2023  20/10/2023
# 12         40000 km   51000\nkm  22/11/2023  21/11/2023
# 13         30000 km   41000\nkm  26/11/2023  21/11/2023
# 14        175000 km  181110\nkm  16/09/2023  07/07/2024
# 15        473000 km  491577\nkm  11/05/2024  01/08/2024
# 16        357000 km  368094\nkm  16/02/2024  11/12/2023
# 17        432000 km  440308\nkm  25/08/2023  26/08/2024
# 18        262000 km  106169\nkm  22/11/2023  05/11/2023
# 19         80000 km   93665\nkm  18/01/2024  15/09/2023
# 20        636000 km  656005\nkm  20/07/2024  20/06/2024
# 21        431500 km  436504\nkm  04/08/2023  01/08/2024
# 22        158207 km  178496\nkm  28/12/2022  25/11/2023
# 23        325600 km  320009\nkm  23/02/2023  11/12/2023
# 24        236534 km  216000\nkm  27/07/2023  29/06/2024

# %%
df.dtypes
# Out:
# Name                  object
# Odo / Hours / Hubo    object
# Next Service Due      object
# RUC Due               object
# WoF Due               object
# Rego Due              object
# dtype: object

# %%
# convert 'WoF Due' and 'Rego Due' data from string to datetime
df['WoF Due'] = pd.to_datetime(df['WoF Due'], dayfirst=True)
df['Rego Due'] = pd.to_datetime(df['Rego Due'], dayfirst=True)

# get today's date for comparison
today = datetime.now().date()

# date calculations - subtract 'WoF Due' date from today's date to get days remaining for WOF and Rego renewals
df['WOF Renew'] = (df['WoF Due'] - pd.Timestamp(today)).dt.days
df['Rego Renew'] = (df['Rego Due'] - pd.Timestamp(today)).dt.days

# %%
# cleaning data by removing characters from numbers using regex
# df['Odo / Hours / Hubo'] = pd.Series(df['Odo / Hours / Hubo']).str.findall(r'\d+')
df['Odo / Hours / Hubo'] = (df['Odo / Hours / Hubo']).str.findall(r'\d+')

# get rid of list-like structure and to strings where the elements are joined by comma
df['Odo / Hours / Hubo'] = [','.join(map(str, l)) for l in df['Odo / Hours / Hubo']]

# split values seprated by comma
df['ODO'] = df['Odo / Hours / Hubo'].apply(lambda x: x.split(',')[0])
df['Hubometer'] = df['Odo / Hours / Hubo'].apply(lambda x: x.split(',')[-1])

# get rid of 'km' string at the end
df['Next Service Due'] = (df['Next Service Due']).str.strip('km')

# use regex to fetch only the numbers
df['RUC Due'] = pd.Series(df['RUC Due']).str.findall(r'\b\d+\b')
# get rid of list-like structure and to strings where the elements are joined by comma
df['RUC Due']  = [','.join(map(str, l)) for l in df['RUC Due'] ]

# convert to integer
df['Next Service Due'] = df['Next Service Due'].apply(lambda x: int(x))
df['RUC Due'] = df['RUC Due'].apply(lambda x: int(x))
df['ODO'] = df['ODO'].apply(lambda x: int(x))
df['Hubometer'] = df['Hubometer'].apply(lambda x: int(x))

# calculations
df['RUC Remaining'] = df['RUC Due'] - df['Hubometer']
df['Next Service In'] = df['Next Service Due'] - df['ODO']

# %%
# change date format
df['WoF Due*'] = df['WoF Due'].apply(lambda x: x.strftime('%d-%m-%Y'))
df['Rego Due*'] = df['Rego Due'].apply(lambda x: x.strftime('%d-%m-%Y'))

# %%
# re-ordering column
df = df[['Name','ODO','Hubometer','Next Service Due','RUC Due','Rego Due*','WoF Due*','Next Service In','WOF Renew','Rego Renew','RUC Remaining']]

# %%
df.head()
# Out:
#                    Name     ODO  Hubometer  Next Service Due  RUC Due  \
# 0  101 - JLM368 - Hiace  371971     371971            375000   388652
# 1   102 - LGH14 - Hiace  421977     421977            435000   436000
# 2   103 - LPB86 - Hiace  293533     293533            294500   301948
# 3  104 - LPB87 -  Hiace  271762     271762            283600   288404
# 4  105 - LPK832 - Hiace  297725     297725            314404   308892
#
#     Rego Due*    WoF Due*  Next Service In  WOF Renew  Rego Renew  \
# 0  24-11-2023  16-11-2023             3029         81          89
# 1  19-03-2024  30-04-2024            13023        247         205
# 2  15-08-2024  10-08-2024              967        349         354
# 3  15-08-2024  13-09-2023            11838         17         354
# 4  26-08-2024  23-08-2024            16679        362         365
#
#    RUC Remaining
# 0          16681
# 1          14023
# 2           8415
# 3          16642
# 4          11167

# %%
df.dtypes
# Out:
# Name                object
# ODO                  int64
# Hubometer            int64
# Next Service Due     int64
# RUC Due              int64
# Rego Due*           object
# WoF Due*            object
# Next Service In      int64
# WOF Renew            int64
# Rego Renew           int64
# RUC Remaining        int64
# dtype: object

# %% [markdown]
# # Styling

# %%
df_styled = df.style\
    .applymap(lambda x: 'background-color: %s' % '#ff9966' if x < 0 else ('background-color: %s' % '#99ff99' if 0 <= x <= 5000 else 'background-color: %s' % 'none'), subset=['Next Service In'])\
    .applymap(lambda x: 'background-color: %s' % '#ff9966' if x < 0 else 'background-color: %s' % 'none', subset=['RUC Remaining'])\
    .highlight_between(subset='RUC Remaining',left=0,right=7000, color='#ff9966')\
    .applymap(lambda x: 'background-color: %s' % '#ff9966' if x < 0 else ('background-color: %s' % '#99ff99' if 0 <= x <= 30 else 'background-color: %s' % 'none'), subset=['WOF Renew'])\
    .applymap(lambda x: 'background-color: %s' % '#ff9966' if x < 0 else ('background-color: %s' % '#99ff99' if 0 <= x <= 30 else 'background-color: %s' % 'none'), subset=['Rego Renew'])\
    .format({'RUC Remaining': '{0:,.0f} km', 'Next Service In': '{0:,.0f} km', 'ODO': '{0:,.0f} km', 'Hubometer': '{0:,.0f} km', 'Next Service Due': '{0:,.0f} km', 'RUC Due': '{0:,.0f} km',
             'WOF Renew': '{} Days', 'Rego Renew': '{} Days'})

# %% [markdown]
# # Export to excel

# %%
folder_path_report = Path(r'./report/')
file_path = folder_path_report / 'Report.xlsx'
df_styled.to_excel(file_path, engine='openpyxl', index=False)

# %% [markdown]
# # Report

# %%
df_styled
# Out:
# <style type="text/css">
# #T_9c2fe_row0_col7, #T_9c2fe_row2_col7, #T_9c2fe_row3_col8, #T_9c2fe_row6_col7, #T_9c2fe_row7_col8, #T_9c2fe_row10_col7, #T_9c2fe_row10_col8, #T_9c2fe_row13_col7, #T_9c2fe_row14_col8, #T_9c2fe_row16_col7, #T_9c2fe_row19_col9 {
#   background-color: #99ff99;
# }
# #T_9c2fe_row0_col8, #T_9c2fe_row0_col9, #T_9c2fe_row0_col10, #T_9c2fe_row1_col7, #T_9c2fe_row1_col8, #T_9c2fe_row1_col9, #T_9c2fe_row1_col10, #T_9c2fe_row2_col8, #T_9c2fe_row2_col9, #T_9c2fe_row2_col10, #T_9c2fe_row3_col7, #T_9c2fe_row3_col9, #T_9c2fe_row3_col10, #T_9c2fe_row4_col7, #T_9c2fe_row4_col8, #T_9c2fe_row4_col9, #T_9c2fe_row4_col10, #T_9c2fe_row5_col7, #T_9c2fe_row5_col8, #T_9c2fe_row5_col9, #T_9c2fe_row5_col10, #T_9c2fe_row6_col8, #T_9c2fe_row6_col9, #T_9c2fe_row6_col10, #T_9c2fe_row7_col7, #T_9c2fe_row7_col9, #T_9c2fe_row7_col10, #T_9c2fe_row8_col7, #T_9c2fe_row8_col9, #T_9c2fe_row9_col7, #T_9c2fe_row9_col8, #T_9c2fe_row9_col9, #T_9c2fe_row9_col10, #T_9c2fe_row10_col9, #T_9c2fe_row10_col10, #T_9c2fe_row11_col8, #T_9c2fe_row11_col9, #T_9c2fe_row12_col8, #T_9c2fe_row12_col9, #T_9c2fe_row12_col10, #T_9c2fe_row13_col8, #T_9c2fe_row13_col9, #T_9c2fe_row13_col10, #T_9c2fe_row14_col7, #T_9c2fe_row14_col9, #T_9c2fe_row14_col10, #T_9c2fe_row15_col8, #T_9c2fe_row15_col9, #T_9c2fe_row15_col10, #T_9c2fe_row16_col8, #T_9c2fe_row16_col9, #T_9c2fe_row16_col10, #T_9c2fe_row17_col7, #T_9c2fe_row17_col9, #T_9c2fe_row17_col10, #T_9c2fe_row18_col8, #T_9c2fe_row18_col9, #T_9c2fe_row18_col10, #T_9c2fe_row19_col8, #T_9c2fe_row19_col10, #T_9c2fe_row20_col8, #T_9c2fe_row20_col9, #T_9c2fe_row20_col10, #T_9c2fe_row21_col7, #T_9c2fe_row21_col9, #T_9c2fe_row21_col10, #T_9c2fe_row22_col9, #T_9c2fe_row22_col10, #T_9c2fe_row23_col7, #T_9c2fe_row23_col9, #T_9c2fe_row23_col10, #T_9c2fe_row24_col7, #T_9c2fe_row24_col9, #T_9c2fe_row24_col10 {
#   background-color: none;
# }
# #T_9c2fe_row8_col8, #T_9c2fe_row11_col7, #T_9c2fe_row12_col7, #T_9c2fe_row15_col7, #T_9c2fe_row17_col8, #T_9c2fe_row18_col7, #T_9c2fe_row19_col7, #T_9c2fe_row20_col7, #T_9c2fe_row21_col8, #T_9c2fe_row22_col7, #T_9c2fe_row22_col8, #T_9c2fe_row23_col8, #T_9c2fe_row24_col8 {
#   background-color: #ff9966;
# }
# #T_9c2fe_row8_col10, #T_9c2fe_row11_col10 {
#   background-color: none;
#   background-color: #ff9966;
# }
# </style>
# <table id="T_9c2fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c2fe_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_9c2fe_level0_col1" class="col_heading level0 col1" >ODO</th>
#       <th id="T_9c2fe_level0_col2" class="col_heading level0 col2" >Hubometer</th>
#       <th id="T_9c2fe_level0_col3" class="col_heading level0 col3" >Next Service Due</th>
#       <th id="T_9c2fe_level0_col4" class="col_heading level0 col4" >RUC Due</th>
#       <th id="T_9c2fe_level0_col5" class="col_heading level0 col5" >Rego Due*</th>
#       <th id="T_9c2fe_level0_col6" class="col_heading level0 col6" >WoF Due*</th>
#       <th id="T_9c2fe_level0_col7" class="col_heading level0 col7" >Next Service In</th>
#       <th id="T_9c2fe_level0_col8" class="col_heading level0 col8" >WOF Renew</th>
#       <th id="T_9c2fe_level0_col9" class="col_heading level0 col9" >Rego Renew</th>
#       <th id="T_9c2fe_level0_col10" class="col_heading level0 col10" >RUC Remaining</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c2fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c2fe_row0_col0" class="data row0 col0" >101 - JLM368 - Hiace</td>
#       <td id="T_9c2fe_row0_col1" class="data row0 col1" >371,971 km</td>
#       <td id="T_9c2fe_row0_col2" class="data row0 col2" >371,971 km</td>
#       <td id="T_9c2fe_row0_col3" class="data row0 col3" >375,000 km</td>
#       <td id="T_9c2fe_row0_col4" class="data row0 col4" >388,652 km</td>
#       <td id="T_9c2fe_row0_col5" class="data row0 col5" >24-11-2023</td>
#       <td id="T_9c2fe_row0_col6" class="data row0 col6" >16-11-2023</td>
#       <td id="T_9c2fe_row0_col7" class="data row0 col7" >3,029 km</td>
#       <td id="T_9c2fe_row0_col8" class="data row0 col8" >81 Days</td>
#       <td id="T_9c2fe_row0_col9" class="data row0 col9" >89 Days</td>
#       <td id="T_9c2fe_row0_col10" class="data row0 col10" >16,681 km</td>
#     </tr>
#     <tr>
#       <th id="T_9c2fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c2fe_row1_col0" class="data row1 col0" >102 - LGH14 - Hiace</td>
#       <td id="T_9c2fe_row1_col1" class="data row1 col1" >421,977 km</td>
#       <td id="T_9c2fe_row1_col2" class="data row1 col2" >421,977 km</td>
#       <td id="T_9c2fe_row1_col3" class="data row1 col3" >435,000 km</td>
#       <td id="T_9c2fe_row1_col4" class="data row1 col4" >436,000 km</td>
#       <td id="T_9c2fe_row1_col5" class="data row1 col5" >19-03-2024</td>
#       <td id="T_9c2fe_row1_col6" class="data row1 col6" >30-04-2024</td>
#       <td id="T_9c2fe_row1_col7" class="data row1 col7" >13,023 km</td>
#       <td id="T_9c2fe_row1_col8" class="data row1 col8" >247 Days</td>
#       <td id="T_9c2fe_row1_col9" class="data row1 col9" >205 Days</td>
#       <td id="T_9c2fe_row1_col10" class="data row1 col10" >14,023 km</td>
#     </tr>
#     <tr>
#       <th id="T_9c2fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c2fe_row2_col0" class="data row2 col0" >103 - LPB86 - Hiace</td>
#       <td id="T_9c2fe_row2_col1" class="data row2 col1" >293,533 km</td>
#       <td id="T_9c2fe_row2_col2" class="data row2 col2" >293,533 km</td>
#       <td id="T_9c2fe_row2_col3" class="data row2 col3" >294,500 km</td>
#       <td id="T_9c2fe_row2_col4" class="data row2 col4" >301,948 km</td>
#       <td id="T_9c2fe_row2_col5" class="data row2 col5" >15-08-2024</td>
#       <td id="T_9c2fe_row2_col6" class="data row2 col6" >10-08-2024</td>
#       <td id="T_9c2fe_row2_col7" class="data row2 col7" >967 km</td>
#       <td id="T_9c2fe_row2_col8" class="data row2 col8" >349 Days</td>
#       <td id="T_9c2fe_row2_col9" class="data row2 col9" >354 Days</td>
#       <td id="T_9c2fe_row2_col10" class="data row2 col10" >8,415 km</td>
#     </tr>
#     <tr>
#       <th id="T_9c2fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c2fe_row3_col0" class="data row3 col0" >104 - LPB87 -  Hiace</td>
#       <td id="T_9c2fe_row3_col1" class="data row3 col1" >271,762 km</td>
#       <td id="T_9c2fe_row3_col2" class="data row3 col2" >271,762 km</td>
#       <td id="T_9c2fe_row3_col3" class="data row3 col3" >283,600 km</td>
#       <td id="T_9c2fe_row3_col4" class="data row3 col4" >288,404 km</td>
#       <td id="T_9c2fe_row3_col5" class="data row3 col5" >15-08-2024</td>
#       <td id="T_9c2fe_row3_col6" class="data row3 col6" >13-09-2023</td>
#       <td id="T_9c2fe_row3_col7" class="data row3 col7" >11,838 km</td>
#       <td id="T_9c2fe_row3_col8" class="data row3 col8" >17 Days</td>
#       <td id="T_9c2fe_row3_col9" class="data row3 col9" >354 Days</td>
#       <td id="T_9c2fe_row3_col10" class="data row3 col10" >16,642 km</td>
#     </tr>
#     <tr>
#       <th id="T_9c2fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c2fe_row4_col0" class="data row4 col0" >105 - LPK832 - Hiace</td>
#       <td id="T_9c2fe_row4_col1" class="data row4 col1" >297,725 km</td>
#       <td id="T_9c2fe_row4_col2" class="data row4 col2" >297,725 km</td>
#       <td id="T_9c2fe_row4_col3" class="data row4 col3" >314,404 km</td>
#       <td id="T_9c2fe_row4_col4" class="data row4 col4" >308,892 km</td>
#       <td id="T_9c2fe_row4_col5" class="data row4 col5" >26-08-2024</td>
#       <td id="T_9c2fe_row4_col6" class="data row4 col6" >23-08-2024</td>
#       <td id="T_9c2fe_row4_col7" class="data row4 col7" >16,679 km</td>
#       <td id="T_9c2fe_row4_col8" class="data row4 col8" >362 Days</td>
#       <td id="T_9c2fe_row4_col9" class="data row4 col9" >365 Days</td>
#       <td id="T_9c2fe_row4_col10" class="data row4 col10" >11,167 km</td>
#     </tr>
#     <tr>
#       <th id="T_9c2fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c2fe_row5_col0" class="data row5 col0" >106 - KBW622 - KK Hiace (small chiller)</td>
